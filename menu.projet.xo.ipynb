# %%
import random
import numpy as np
import sys
from sqlalchemy import true
dictionar = dict()

print ('=== raws are LETTERS == columns are NUMBERS ===')
print ('                GAME STARTED                    ')
print (' ')
print (' ')
print (' 0   0   0 ' '==>'' ' 'a1''-' 'a2''-' 'a3')
print (' 0   0   0 ' '==>'' ' 'b1''-' 'b2''-' 'b3')
print (' 0   0   0 ' '==>'' ' 'c1''-' 'c2''-' 'c3')
print (' ')
print (' ')




list = ['a1', 'a2', 'a3', 'b1', 'b2', 'b3', 'c1', 'c2', 'c3']
 
def Roll(l):
    return (np.random.choice(l,replace=true))


def princip():

    global list 
    dictionar = {'a1' : '-', 'a2' : '-', 'a3' : '-', 'b1' : '-', 'b2' : '-', 'b3' : '-', 'c1' : '-', 'c2' : '-', 'c3' :'-'}
    
    i=0
    while True:

                    
                        if len(list) > 0 : 
                            x=Roll(list)
                         
                        #the user move
                            for word in dictionar:
                                        if x in word:
                                            dictionar[x] = 'X'
                                        if x in list:
                                            list.remove(x)
                        ## print ('Computer1 move is:',x)  

                        ##print("*************************************************************")

                        if len(list) > 0 :                 							   #computer move
                            o=Roll(list)
                           
                            for word in dictionar :
                                    if o in word:
                                        dictionar[o] = 'O' 
                                    if o in list:
                                        list.remove(o)
                        ##  print ('Computer2 move is:',o)

                        else :
                          return 0
            
               
                     
                             
                            
                    

                    ## print("*************************************************************")
                    #print the grafic

                        ##print (dictionar['a1'], dictionar['a2'], dictionar['a3'])
                        ##print (dictionar['b1'], dictionar['b2'], dictionar['b3'])
                        ##print (dictionar['c1'], dictionar['c2'], dictionar['c3'])

                        #who won
                        

        

                        if dictionar['a1'] == dictionar['a2'] == dictionar['a3'] == 'X':
                           
                            
                            return 1
                        elif dictionar['b1'] == dictionar['b2'] == dictionar['b3'] == 'X':
                             
                           
                          
                            return 1
                        elif dictionar['c1'] == dictionar['c2'] == dictionar['c3'] == 'X':
                           
                            return 1
                            
                        elif dictionar['a1'] == dictionar['b1'] == dictionar['c1'] == 'X':
                           
                            return 1
                               
                        elif dictionar['a2'] == dictionar['b2'] == dictionar['c2'] == 'X':
                           
                            return 1
                            
                        elif dictionar['a3'] == dictionar['b3'] == dictionar['c3'] == 'X':
                           
                            return 1
                               
                        elif dictionar['c1'] == dictionar['b2'] == dictionar['a3'] == 'X':
                           
                            return 1
                            
                        elif dictionar['a1'] == dictionar['b2'] == dictionar['c3'] == 'X':
                           
                            return 1
                            
                        
                        elif dictionar['a1'] == dictionar['a2'] == dictionar['a3'] == 'O':
                            
                            return 2
                            
                        elif dictionar['b1'] == dictionar['b2'] == dictionar['b3'] == 'O':
                            
                            return 2
                            
                        elif dictionar['c1'] == dictionar['c2'] == dictionar['c3'] == 'O':
                            
                            return 2
                            
                        elif dictionar['a1'] == dictionar['b1'] == dictionar['c1'] == 'O':
                            
                            return 2
                               
                        elif dictionar['a2'] == dictionar['b2'] == dictionar['c2'] == 'O':
                            
                            return 2
                            
                        elif dictionar['a3'] == dictionar['b3'] == dictionar['c3'] == 'O':
                            
                            return 2
                               
                        elif dictionar['c1'] == dictionar['b2'] == dictionar['a3'] == 'O':
                            
                            return 2
                            
                        elif dictionar['a1'] == dictionar['b2'] == dictionar['c3'] == 'O':
                            
                            return 2
# Out:
# === raws are LETTERS == columns are NUMBERS ===
#                 GAME STARTED
#
#
#  0   0   0 ==> a1-a2-a3
#  0   0   0 ==> b1-b2-b3
#  0   0   0 ==> c1-c2-c3

# %%
test=10
l=[]
for i in range (test):
  l.append(princip())


print (l)
# Out:
# [2, 0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
n=1000
l=[princip()for k in range(n)]
p1=(l.count(1)/n)*100
p2=(l.count(2)/n)*100
px=(l.count(0)/n)*100
print(f'%p1 gange={p1}, %p2 gange={p2}, %matchrul={p2}')
# Out:
# %p1 gange=0.0, %p2 gange=0.0, %matchrul=0.0
